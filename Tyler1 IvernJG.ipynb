# %% [markdown]
# # Imports

# %%
import urllib.request, urllib.parse, urllib.error
from datetime import datetime
import csv
import time

# %% [markdown]
# # Functions

# %% [markdown]
# periodic work: timer (1800s) = 30 minutes
# detData: scrape important stats from op.gg

# %%
def periodic_work(interval):
    while True:
        getData()
        time.sleep(interval)
        
        
        
def getData():
    fhand = urllib.request.urlopen('https://na.op.gg/summoner/userName=S8+IS+SO+FUN')
    text =""
    for line in fhand:
        text += line.decode()
    
    #daterecorded
    rectime = datetime.now()
    #player
    player = "T1: S8 IS SO FUN"                                                          #Hardcoded

    #season
    season = 10.5                                                                           #Hardcoded/unsure on s11 start
    if "2021-01-20" in str(rectime):
        season = 11

    #Ladder Position Euw
    ladderind = text.find('Ladder Rank')
    ladderpos = text[ladderind: ladderind+65: 1].rsplit("(")[1][0: 4: 1]

    #Ranked Solo
    tierind = text.find('<div class="TierRank">')
    solotier = text[tierind: tierind+35: 1].rsplit(">")[1].strip("</div")

    #LP Solo
    LPind = text.find('<span class="LeaguePoints">')
    LPscore = text[LPind: LPind+40: 1].rsplit(">")[1].strip('\n').strip('\t').strip('\n')

    #Solo wins
    soloWind = text.find('<span class="wins">')
    soloW = text[soloWind: soloWind+30: 1].rsplit(">")[1].strip("</span")

    #Solo Losses
    soloLind = text.find('<span class="losses">')
    soloL = text[soloLind: soloLind+30: 1].rsplit(">")[1].strip("</spa")



    #print
    print(rectime)
    print(player)
    print(season)
    print(ladderpos)
    print(solotier)
    print(LPscore)
    print(soloW)
    print(soloL)

    with open('tlhulk.csv', 'a') as f:
        wr = csv.writer(f)
        wr.writerow([rectime,player,season,ladderpos,solotier,LPscore,soloW,soloL])

        
periodic_work(1800)
# Out:
# 2020-11-12 20:55:38.041921
# T1: S8 IS SO FUN
# 10.5
# 1.16
# Diamond 4
# 50 LP
# 347W
# 363L
# 2020-11-12 21:25:38.712414
# T1: S8 IS SO FUN
# 10.5
# 1.16
# Diamond 4
# 50 LP
# 347W
# 363L
# 2020-11-12 21:55:39.421816
# T1: S8 IS SO FUN
# 10.5
# 1.16
# Diamond 4
# 50 LP
# 347W
# 363L
# 2020-11-12 22:25:39.927952
# T1: S8 IS SO FUN
# 10.5
# 1.16
# Diamond 4
# 50 LP
# 347W
# 363L
# 2020-11-12 22:55:40.609767
# T1: S8 IS SO FUN
# 10.5
# 1.03
# Diamond 4
# 74 LP
# 349W
# 365L
# 2020-11-12 23:25:41.260596
# T1: S8 IS SO FUN
# 10.5
# 1.03
# Diamond 4
# 61 LP
# 349W
# 366L
# 2020-11-12 23:55:41.898992
# T1: S8 IS SO FUN
# 10.5
# 1.09
# Diamond 4
# 61 LP
# 349W
# 366L
# 2020-11-13 00:25:42.760825
# T1: S8 IS SO FUN
# 10.5
# 1.09
# Diamond 4
# 61 LP
# 349W
# 366L
# 2020-11-13 00:55:43.595831
# T1: S8 IS SO FUN
# 10.5
# 1.29
# Diamond 4
# 34 LP
# 349W
# 368L
# 2020-11-13 01:25:44.187785
# T1: S8 IS SO FUN
# 10.5
# 1.29
# Diamond 4
# 34 LP
# 349W
# 368L
